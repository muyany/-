# %% [markdown]
# # 五.图像融合、加法运算及图像类型转换

# %% [markdown]
# 本章讲解Python调用OpenCV实现图像融合及加法运算，包括三部分知识：
#
# 1.图像加法运算
#
# 2.图像融合
#
# 3.图像类型转换

# %% [markdown]
# ## 5.1图像加法运算

# %% [markdown]
# 1.Numpy库加法其运算方法是：目标图像 = 图像1 + 图像2，运算结果进行取模运算
#
# 当像素值<=255时，结果为“图像1+图像2”，例如：120+48=168当像素值>255时，结果为对255取模的结果，例如：(255+64)%255=64
#
# 2.OpenCV加法运算另一种方法是直接调用OpenCV库实现图像加法运算，方法如下：目标图像 = cv2.add(图像1, 图像2)此时结果是饱和运算，即：
#
# 当像素值<=255时，结果为“图像1+图像2”，例如：120+48=168
#
# 当像素值>255时，结果为255，例如：(255+64) = 255
#
# 代码实现

# %%
import cv2  
import numpy as np  
import matplotlib.pyplot as plt
#读取图片
img = cv2.imread('test.jpg')
test = img
#方法一：Numpy加法运算
result1 = img + test
#方法二：OpenCV加法运算
result2 = cv2.add(img, test)
#显示图像
cv2.imshow("original", img)
cv2.imshow("result1", result1)
cv2.imshow("result2", result2)
#等待显示
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 输出结果如上图所示，其中result1为第一种方法，result2为第二种方法，白色点255更多

# %% [markdown]
# 注意：参与运算的图像大小和类型必须一致。下面是对彩色图像进行加法运算的结果

# %% [markdown]
# ## 5.2图像融合

# %% [markdown]
# 图像融合通常是指将2张或2张以上的图像信息融合到1张图像上，融合的图像含有更多的信息，能够更方便人们观察或计算机处理。如下图所示，将两张不清晰的图像融合得到更清晰的图。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 图像融合是在图像加法的基础上增加了系数和亮度调节量。
#
# 图像加法：目标图像 = 图像1 + 图像2
#
# 图像融合：目标图像 = 图像1 * 系数1 + 图像2 * 系数2 + 亮度调节量
#
# 主要调用的函数是addWeighted，方法如下：dst = cv2.addWeighter(scr1, alpha, src2, beta, gamma)dst = src1 * alpha + src2 * beta + gamma其中参数gamma不能省略。
#
# 代码如下

# %%
import cv2  
import numpy as np  
import matplotlib.pyplot as plt
 
#读取图片
src1 = cv2.imread('test.jpg')
src2 = cv2.imread('test2.jpg')

#图像融合
result = cv2.addWeighted(src1, 1, src2, 1, 0)

#显示图像
cv2.imshow("src1", src1)
cv2.imshow("src2", src2)
cv2.imshow("result", result)

#等待显示
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 需要注意的是，
# 两张融合的图像像素
# 大小需要一致，
# 如下图所示，
# 将两张RGB且
# 像素400*400的图像融合

# %% [markdown]
# 设置不同的比例的融合如下所示：result = cv2.addWeighted(src1, 0.6, src2, 0.8, 10)

# %%
import cv2  
import numpy as np  
import matplotlib.pyplot as plt
 
#读取图片
src1 = cv2.imread('test.jpg')
src2 = cv2.imread('test2.jpg')

result = cv2.addWeighted(src1, 0.6, src2, 0.8, 10)
#显示图像
cv2.imshow("result", result)

#等待显示
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 5.3图像类型转换

# %% [markdown]
# 图像类型转换是指将一种类型转换为另一种类型，比如彩色图像转换为灰度图像、BGR图像转换为RGB图像。OPenCV提供了200多种不同类型之间的转换，其中最常用的包括3类，如下：
#
# cv2.COLOR_BGR2GRAY
#
# cv2.COLOR_BGR2RGB
#
# cv2.COLOR_GRAY2BGR
#
# 代码如下:

# %%
import cv2  
import numpy as np  
import matplotlib.pyplot as plt
 
#读取图片
src = cv2.imread('test.jpg')

#图像类型转换
result = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

#显示图像
cv2.imshow("src", src)
cv2.imshow("result", result)

#等待显示
cv2.waitKey(0)
cv2.destroyAllWindows()
